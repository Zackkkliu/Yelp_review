# %%
import pandas as pd
import numpy as np
import sqlalchemy as sqla
import random
import spacy
from spacy.util import minibatch, compounding
import time

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# **It's important to use sentiments to evaluate the review of business. Although 'stars' seems to be a sufficient estimator, it lacks objectivity. A person can give different stars under his/her certain mood even though the actual quality of the business is constant. Thus, bringing up sentiment into account is a good way of measuring the actually quality of the business**

# %%
# construct connection to database
conn = sqla.create_engine('sqlite:///yelp.sqlite')

# %%
# query data from database
test = pd.read_sql_query("select * from review limit 20",conn)

# %%
test['text'][0]
# Out:
# "The pizza was okay. Not the best I've had. I prefer Biaggio's on Flamingo / Fort Apache. The chef there can make a MUCH better NY style pizza. The pizzeria @ Cosmo was over priced for the quality and lack of personality in the food. Biaggio's is a much better pick if youre going for italian - family owned, home made recipes, people that actually CARE if you like their food. You dont get that at a pizzeria in a casino. I dont care what you say..."

# %% [markdown]
# ## Textblob classifier

# %%
# %%time
# Default estimator
m = test['text'][2]
import textblob
from textblob import TextBlob
senti = TextBlob(m)
print(senti.sentiment)
# Out:
# Sentiment(polarity=-0.5333333333333333, subjectivity=0.8)
# CPU times: user 1.4 ms, sys: 1.02 ms, total: 2.42 ms
# Wall time: 3.86 ms

# %%
# %%time
# NaiveBayes estimator:
from textblob.sentiments import NaiveBayesAnalyzer
senti = TextBlob(m,analyzer=NaiveBayesAnalyzer())
print(senti.sentiment)
# Out:
# Sentiment(classification='pos', p_pos=0.9136346853028313, p_neg=0.08636531469717702)
# CPU times: user 4.15 s, sys: 514 ms, total: 4.66 s
# Wall time: 5.23 s

# %% [markdown]
# **textblob doesn't have a acceptable accuracy especially for food review. Naivebayes is slow and inaccurate. I did a little research on how textblob calculates the sentiment. It turns out they have a XML file that contains polarity score for each words, and the overall polarity score is just the average of polarity scores of each word (Link: https://planspace.org/20150607-textblob_sentiment/ ). This is a poor way of estimating the sentiment score. Consider training my own NLP model.**

# %% [markdown]
# # SpaCy Text Categorizer
# I will train the model with Amazon's food review

# %%
amz_review = pd.read_csv('Amazon_Reviews.csv')
amz_review.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
# rescale score between -1 and 1
norm_score = np.interp(amz_review.Score.values,(amz_review.Score.values.min(),amz_review.Score.values.max()),(-1,+1))

# %%
amz_review['norm_score'] = norm_score

# %%
amz_review['train_tuple'] = amz_review.apply(lambda row: (row['Text'],row['Score']),axis=1)
train = amz_review['train_tuple'].tolist()
train[0]
# Out:
# ('I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.',
#  5)

# %%
#functions from spacy documentation
def load_data(limit=0, split=0.8):
    train_data = train
    np.random.shuffle(train_data)
    train_data = train_data[-limit:]
    texts, labels = zip(*train_data)
    cats = [{'POSITIVE': y >= 3} for y in labels]
    split = int(len(train_data) * split)
    return (texts[:split], cats[:split]), (texts[split:], cats[split:])

def evaluate(tokenizer, textcat, texts, cats):
    docs = (tokenizer(text) for text in texts)
    tp = 1e-8  # True positives
    fp = 1e-8  # False positives
    fn = 1e-8  # False negatives
    tn = 1e-8  # True negatives
    for i, doc in enumerate(textcat.pipe(docs)):
        gold = cats[i]
        for label, score in doc.cats.items():
            if label not in gold:
                continue
            if score >= 0.5 and gold[label] >= 0.5:
                tp += 1.
            elif score >= 0.5 and gold[label] < 0.5:
                fp += 1.
            elif score < 0.5 and gold[label] < 0.5:
                tn += 1
            elif score < 0.5 and gold[label] >= 0.5:
                fn += 1
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f_score = 2 * (precision * recall) / (precision + recall)
    return {'textcat_p': precision, 'textcat_r': recall, 'textcat_f': f_score}

# %%
#("Number of texts to train from","t" , int)
n_texts=300000
#You can increase texts count if you have more computational power.
#("Number of training iterations", "n", int))
n_iter=10

# %%
nlp = spacy.load('en_core_web_sm')  # create english Language class

# %%
# add the text classifier to the pipeline if it doesn't exist
# nlp.create_pipe works for built-ins that are registered with spaCy
if 'textcat' not in nlp.pipe_names:
    textcat = nlp.create_pipe('textcat')
    nlp.add_pipe(textcat, last=True)
# otherwise, get it, so we can add labels to it
else:
    textcat = nlp.get_pipe('textcat')

# add label to text classifier
textcat.add_label('POSITIVE')

# load the dataset
print("Loading food reviews data...")
(train_texts, train_cats), (dev_texts, dev_cats) = load_data(limit=n_texts)
print("Using {} examples ({} training, {} evaluation)"
      .format(n_texts, len(train_texts), len(dev_texts)))
train_data = list(zip(train_texts,
                      [{'cats': cats} for cats in train_cats]))
# Out:
# Loading food reviews data...
# Using 30000 examples (24000 training, 6000 evaluation)

# %%
# %%time
# Training
# get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'textcat']
with nlp.disable_pipes(*other_pipes):  # only train textcat
    optimizer = nlp.begin_training()
    print("Training the model...")
    print('{:^5}\t{:^5}\t{:^5}\t{:^5}'.format('LOSS', 'P', 'R', 'F'))
    for i in range(n_iter):
        start = time.time()
        losses = {}
        # batch up the examples using spaCy's minibatch
        batches = minibatch(train_data, size=compounding(4., 32., 1.001))
        for batch in batches:
            texts, annotations = zip(*batch)
            nlp.update(texts, annotations, sgd=optimizer, drop=0.2,
                       losses=losses)
        with textcat.model.use_params(optimizer.averages):
            # evaluate on the dev data split off in load_data()
            scores = evaluate(nlp.tokenizer, textcat, dev_texts, dev_cats)
        stop = time.time()
        print('{0:.3f}\t{1:.3f}\t{2:.3f}\t{3:.3f}'  # print a simple table
              .format(losses['textcat'], scores['textcat_p'],
                      scores['textcat_r'], scores['textcat_f']))
        print('time for one iteration is {}'.format(stop-start))
# Out:
# Warning: Unnamed vectors -- this won't allow multiple vectors models to be loaded. (Shape: (0, 0))
# Training the model...
# LOSS 	  P  	  R  	  F
# 204.768	0.910	0.983	0.945
# time for one iteration is 155.03080892562866
# 123.836	0.925	0.975	0.949
# time for one iteration is 178.083074092865
# 94.492	0.930	0.973	0.951
# time for one iteration is 176.36578583717346
# 84.068	0.934	0.969	0.951
# time for one iteration is 181.42677283287048
# 74.010	0.934	0.969	0.951
# time for one iteration is 185.3597228527069
# 68.926	0.933	0.969	0.950
# time for one iteration is 188.23954820632935
# 64.172	0.935	0.966	0.950
# time for one iteration is 177.8659210205078
# 60.054	0.935	0.968	0.951
# time for one iteration is 180.7558081150055
# 63.498	0.935	0.968	0.951
# time for one iteration is 178.3223419189453
# 57.024	0.936	0.968	0.951
# time for one iteration is 174.05425381660461
# CPU times: user 48min 14s, sys: 1min 54s, total: 50min 9s
# Wall time: 29min 35s

# %%
doc = nlp(test['text'][2])
doc.cats
# Out:
# {'POSITIVE': 0.0005693367565982044}

# %%
test_text2 = 'This tea is fun to watch as the flower expands in the water. Very smooth taste and can be used again and again in the same day. If you love tea, you gotta try these "flowering teas"'
doc2 = nlp(test_text2)
doc2.cats
# Out:
# {'POSITIVE': 0.9758155345916748}

# %% [markdown]
# **The trained model doesn't perform well as well. Have to train on more datasets and see the result. Now, try google NLP api**

# %% [markdown]
# # Google NLP API

# %%
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/Users/jixingwei/Desktop/STA_141b_project/yelp_review.json"

# %%
# Instantiates a client
client = language.LanguageServiceClient()

# The text to analyze
text = u'Hello, world!'
document = types.Document(
    content=text,
    type=enums.Document.Type.PLAIN_TEXT)

# Detects the sentiment of the text
sentiment = client.analyze_sentiment(document=document).document_sentiment

print('Text: {}'.format(text))
print('Sentiment: {}, {}'.format(sentiment.score, sentiment.magnitude))
# Out:
# Text: Hello, world!
# Sentiment: 0.30000001192092896, 0.30000001192092896

# %%
# Instantiates a client
client = language.LanguageServiceClient()

def AnalyseSentiment(text):
    document = types.Document(content=text,type=enums.Document.Type.PLAIN_TEXT)
    # Detects the sentiment of the text
    sentiment = client.analyze_sentiment(document=document).document_sentiment
    return (sentiment.score, sentiment.magnitude)

# %% [markdown]
# Load 3500 samples

# %%
df = pd.read_sql_query("select * from review limit 3500",conn)
df.head()
# Out:
#               business_id  cool                        date  funny  \
# 0  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-02-25 00:00:00.000000      0
# 1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13 00:00:00.000000      0
# 2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23 00:00:00.000000      1
# 3  elqbBhBfElMNSrjFqW3now     0  2011-02-25 00:00:00.000000      0
# 4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05 00:00:00.000000      0
#
#                 review_id  stars  \
# 0  x7mDIiDB3jEiPGPHOmDzyw      2
# 1  dDl8zu1vWPdKGihJrwQbpw      5
# 2  LZp4UX5zK3e-c5ZGSeo3kA      1
# 3  Er4NBWCmCD4nM8_p1GRdow      2
# 4  jsDu6QEJHbwP2Blom1PLCA      5
#
#                                                 text  useful  \
# 0  The pizza was okay. Not the best I've had. I p...       0
# 1  I love this place! My fiance And I go here atl...       0
# 2  Terrible. Dry corn bread. Rib tips were all fa...       3
# 3  Back in 2005-2007 this place was my FAVORITE t...       2
# 4  Delicious healthy food. The steak is amazing. ...       0
#
#                   user_id
# 0  msQe1u7Z_XuqjGoqhB0J5g
# 1  msQe1u7Z_XuqjGoqhB0J5g
# 2  msQe1u7Z_XuqjGoqhB0J5g
# 3  msQe1u7Z_XuqjGoqhB0J5g
# 4  msQe1u7Z_XuqjGoqhB0J5g

# %%
AnalyseSentiment(df['text'][0])
# Out:
# (-0.10000000149011612, 3.200000047683716)

# %%
df['score'] = df['text'].apply(lambda text: AnalyseSentiment(text)[0])

# %%
df.head()
# Out:
#               business_id  cool                        date  funny  \
# 0  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-02-25 00:00:00.000000      0
# 1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13 00:00:00.000000      0
# 2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23 00:00:00.000000      1
# 3  elqbBhBfElMNSrjFqW3now     0  2011-02-25 00:00:00.000000      0
# 4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05 00:00:00.000000      0
#
#                 review_id  stars  \
# 0  x7mDIiDB3jEiPGPHOmDzyw      2
# 1  dDl8zu1vWPdKGihJrwQbpw      5
# 2  LZp4UX5zK3e-c5ZGSeo3kA      1
# 3  Er4NBWCmCD4nM8_p1GRdow      2
# 4  jsDu6QEJHbwP2Blom1PLCA      5
#
#                                                 text  useful  \
# 0  The pizza was okay. Not the best I've had. I p...       0
# 1  I love this place! My fiance And I go here atl...       0
# 2  Terrible. Dry corn bread. Rib tips were all fa...       3
# 3  Back in 2005-2007 this place was my FAVORITE t...       2
# 4  Delicious healthy food. The steak is amazing. ...       0
#
#                   user_id  test_score  score
# 0  msQe1u7Z_XuqjGoqhB0J5g          -2   -0.1
# 1  msQe1u7Z_XuqjGoqhB0J5g          -5    0.7
# 2  msQe1u7Z_XuqjGoqhB0J5g          -1   -0.3
# 3  msQe1u7Z_XuqjGoqhB0J5g          -2   -0.2
# 4  msQe1u7Z_XuqjGoqhB0J5g          -5    0.7

# %%
df.drop(columns=['test_score'],inplace=True)

# %%
df.head()
# Out:
#               business_id  cool                        date  funny  \
# 0  iCQpiavjjPzJ5_3gPD5Ebg     0  2011-02-25 00:00:00.000000      0
# 1  pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13 00:00:00.000000      0
# 2  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23 00:00:00.000000      1
# 3  elqbBhBfElMNSrjFqW3now     0  2011-02-25 00:00:00.000000      0
# 4  Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05 00:00:00.000000      0
#
#                 review_id  stars  \
# 0  x7mDIiDB3jEiPGPHOmDzyw      2
# 1  dDl8zu1vWPdKGihJrwQbpw      5
# 2  LZp4UX5zK3e-c5ZGSeo3kA      1
# 3  Er4NBWCmCD4nM8_p1GRdow      2
# 4  jsDu6QEJHbwP2Blom1PLCA      5
#
#                                                 text  useful  \
# 0  The pizza was okay. Not the best I've had. I p...       0
# 1  I love this place! My fiance And I go here atl...       0
# 2  Terrible. Dry corn bread. Rib tips were all fa...       3
# 3  Back in 2005-2007 this place was my FAVORITE t...       2
# 4  Delicious healthy food. The steak is amazing. ...       0
#
#                   user_id  score
# 0  msQe1u7Z_XuqjGoqhB0J5g   -0.1
# 1  msQe1u7Z_XuqjGoqhB0J5g    0.7
# 2  msQe1u7Z_XuqjGoqhB0J5g   -0.3
# 3  msQe1u7Z_XuqjGoqhB0J5g   -0.2
# 4  msQe1u7Z_XuqjGoqhB0J5g    0.7

# %%
df.to_csv('review_with_score.csv')

# %%
df[df.score < 0]
# Out:
#                  business_id  cool                        date  funny  \
# 0     iCQpiavjjPzJ5_3gPD5Ebg     0  2011-02-25 00:00:00.000000      0
# 2     jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23 00:00:00.000000      1
# 3     elqbBhBfElMNSrjFqW3now     0  2011-02-25 00:00:00.000000      0
# 5     vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25 00:00:00.000000      0
# 11    UBv8heCQR0RPnUQG0zkXIQ     0  2016-09-23 00:00:00.000000      0
# 21    u73j2VQ3TGWdMO-AG7MABw     0  2017-07-06 00:00:00.000000      0
# 23    3Mx4renubPRnjHUw1n2UkA     0  2015-09-30 00:00:00.000000      1
# 26    yz66FIUPDKGhILDWzRLeKg     0  2017-11-18 00:00:00.000000      0
# 32    Edr6SafmQrZa6CcFuItoqg     0  2014-06-03 00:00:00.000000      0
# 38    7xA6iSP0Ndn08tpBFQtUKA     0  2017-05-22 00:00:00.000000      0
# 40    qdC2h3MqCNussc5lhzL7gg     0  2015-11-05 00:00:00.000000      0
# 44    yGZtG3KpoXyvF6gUC0FExQ     0  2016-03-16 00:00:00.000000      0
# 45    Jj8ubiwwuCR-rrhrrjcryw     0  2016-08-14 00:00:00.000000      0
# 46    ERCZtj8qxNxfXJrdXPdEsw     0  2016-04-29 00:00:00.000000      2
# 49    F9cXFXk60E2sz_YTSCFp_Q     0  2016-06-18 00:00:00.000000      0
# 54    -YR7K3rw6VAQ1-MjslvsoQ     0  2016-06-18 00:00:00.000000      0
# 55    1VKjDpPJdVoiRc8I9f7U9g     0  2016-06-11 00:00:00.000000      0
# 60    00liP5s4IKsq97EH4Cc0Tw     0  2016-06-09 00:00:00.000000      0
# 72    SvlTuwslYKdqvqWtDe2dgA     1  2017-01-22 00:00:00.000000      1
# 76    XGLGvB8S6-Anmt7gZkPLkQ     0  2016-06-18 00:00:00.000000      0
# 79    yz3KtngrF2PQrif8JW7gdw     0  2016-05-28 00:00:00.000000      0
# 86    K1rAToLggkTvjRz46IU-Tg     0  2016-06-19 00:00:00.000000      4
# 91    qdx6pWIoBposH9tPph2h9w     0  2013-07-25 00:00:00.000000      0
# 93    uanCi4OGc1mHLGl_AT4JhQ     0  2016-04-04 00:00:00.000000      1
# 94    faPVqws-x-5k2CQKDNtHxw     0  2015-03-25 00:00:00.000000      2
# 98    U2eT17Pf0LQTPGMXN9idxA     0  2017-03-10 00:00:00.000000      0
# 102   aQ222ydz_GSRZV66xNt4kQ     0  2017-04-09 00:00:00.000000      1
# 122   ioEdisf6TTCoUbfQDnUCjA     0  2011-02-27 00:00:00.000000      1
# 123   KuIxm6FVNmlvpssWJi9-bA     1  2010-11-19 00:00:00.000000      2
# 132   uF86ZhygpBEGr3CudNemYA     1  2011-03-17 00:00:00.000000      3
# ...                      ...   ...                         ...    ...
# 3375  eDlgbI0Qg_mmI-Osvci0gw     0  2013-12-03 00:00:00.000000      0
# 3383  -B_4pHQkzU12AMaYkkY4cw     0  2013-03-09 00:00:00.000000      0
# 3385  Egd-0nDgzZGEVA0R09yyUQ     0  2013-03-23 00:00:00.000000      0
# 3386  4bbnMcaVJYlDcTj1vgOvFA     0  2013-01-30 00:00:00.000000      1
# 3387  LwafYd6RYGPnnjoMc0YHaw     0  2012-10-21 00:00:00.000000      0
# 3390  9GPTELAPPpT5vUxad9AoCw     0  2015-05-10 00:00:00.000000      1
# 3394  Yysbic2T_KH2oAflGRBJJQ     0  2015-03-10 00:00:00.000000      0
# 3395  QmIXl-zAw3kBOgnzcLidog     1  2015-03-11 00:00:00.000000      0
# 3403  iWox6NQVA76eH61toMhxfA     0  2015-07-13 00:00:00.000000      1
# 3405  u_vPjx925UPEG9DFOAAvFQ     0  2015-08-04 00:00:00.000000      0
# 3411  7Us3dn3v9o2xMSXA6qztLg     1  2014-11-23 00:00:00.000000      1
# 3416  xLUsM-7yFDnXO7m7Xa420Q     0  2014-02-12 00:00:00.000000      2
# 3418  Q62lGVKqoKJ09lZNt2qpfw     0  2016-03-20 00:00:00.000000      0
# 3421  KSh5L6wADW_fMpG2hMJx8Q     0  2014-01-19 00:00:00.000000      1
# 3424  QXAEGFB4oINsVuTFxEYKFQ     0  2013-09-06 00:00:00.000000      0
# 3428  3k9treY8PmsZ42bKmuICgA     0  2015-02-28 00:00:00.000000      0
# 3435  NOHh2pgOTUBqp82IQlRQMQ     0  2016-05-07 00:00:00.000000      0
# 3436  nDn2h-_c7Xk4UwM0aiXZlw     0  2013-11-16 00:00:00.000000      0
# 3437  aTvzqD5Kot4vp3vOnDyrTw     0  2014-02-24 00:00:00.000000      0
# 3441  UP7ejOl-PQyWZ9iFRQD8Xw     0  2013-09-21 00:00:00.000000      0
# 3446  IBZ6e3P0OqcPXVjvGlpueQ     0  2013-10-01 00:00:00.000000      0
# 3447  9s8D_cDi-HZv6EFiBBY3Uw     0  2014-11-23 00:00:00.000000      0
# 3454  KQEuEJ80wwPqhRNSI3em4A     1  2014-05-05 00:00:00.000000      0
# 3458  aLcFhMe6DDJ430zelCpd2A     0  2013-10-02 00:00:00.000000      0
# 3463  QxSFIWk_hhSloUS6-IIUcg     0  2017-02-22 00:00:00.000000      0
# 3466  MT-lkIacLNyC7KF2dY997A     0  2013-09-12 00:00:00.000000      0
# 3471  CqVdLcbyZzfAjeCD1qEBZQ     2  2014-05-14 00:00:00.000000      2
# 3476  LQ20tGLjCUkuX_bf-mQDfg     0  2016-08-02 00:00:00.000000      0
# 3482  rnCKXjVBrv23nT6Q5G0ZaQ     3  2008-09-28 00:00:00.000000      1
# 3491  xZhCCireQYwcRHh5Nc1Vkw     2  2008-09-27 00:00:00.000000      1
#
#                    review_id  stars  \
# 0     x7mDIiDB3jEiPGPHOmDzyw      2
# 2     LZp4UX5zK3e-c5ZGSeo3kA      1
# 3     Er4NBWCmCD4nM8_p1GRdow      2
# 5     pfavA0hr3nyqO61oupj-lA      1
# 11    HkYqGb0Gplmmk-xlHTRBoA      1
# 21    7EgEjUpcb8q-B5dPCMvkaQ      2
# 23    MTrzrLQT_LK2VLK9xantHw      1
# 26    85DRIjwPJOTb4q0qOlBstw      1
# 32    U04YgYr4PiGUxB46J4xapg      2
# 38    YDJDfKnx6VpMMo4EBxycGg      1
# 40    AJ0IglpYAp2D0daOlVGIdg      1
# 44    U0o92C-o3neVTcE7nSeoeA      2
# 45    3zNW-BK3YlJnGBdCxpE46g      2
# 46    ml9QmqSdQllqSO78RteQfA      1
# 49    tVUDpVAL1eb9BxUwRgJzyA      3
# 54    AxxtdHRnNQMFruSwUDc5jg      3
# 55    eqZvEzaSd_JtWe3oiamjxA      2
# 60    _5VXSwUzadZzLdoxWOyB1Q      3
# 72    a6j2K8RuxCsg_fZ3El9PXA      1
# 76    r0dp0LMAnhzQDoSN3tleBw      1
# 79    SLA1YP9doUc8h-6Kd34QmA      1
# 86    AGBMkc677SGy4q4RbG1NAg      2
# 91    mnh4yY2_jIupURg1r_8pXw      1
# 93    Am8VMrPYMl9WGCpA4ji-gg      1
# 94    QHueaxKHuBpbDOkWb0Cyfw      1
# 98    gh5kRC3s_77jZBUo1Ctw_g      1
# 102   AxhxGl41DItKjqkzYtr53Q      1
# 122   jz8200YeNwsIqa2yImVO_g      1
# 123   UvJkZ8bvLj9iuerrawgoQg      1
# 132   YCilP6BtVj-3Pjq3uTXVwA      1
# ...                      ...    ...
# 3375  E42SDNB-HffM5iL0J0spPQ      3
# 3383  JYVu3cuQX6HJueHkHYxSbw      1
# 3385  0mc53W6rrD6d2h02OwZ-4Q      2
# 3386  5JGyEtzM4JoJVVOhl1-HOA      1
# 3387  RCuVotPSaekz3yECWmXsuA      1
# 3390  bf-XwaiDcF6p5k6ZirtVUQ      1
# 3394  HIYj3qenUoHHyULiw0ZC8g      1
# 3395  g0vURBzjcGJ5hyOxtJhDCQ      1
# 3403  xDUgNhDgRmWa4yjA1RX-PQ      1
# 3405  C47DquAr6DbzLjBlaqtT1w      1
# 3411  yhYXBKT6qC8WZ3Eq1M7HDQ      2
# 3416  buVAAteP-Egxiq99Lf2A7Q      1
# 3418  svpLfASw8QqePmFPTCXaNw      2
# 3421  ezOQlSJ-t3M2kDb_2fYLnA      2
# 3424  za9t9Gxy8H6smd2XaJVZ0g      1
# 3428  VsyDqL8vzTsnO3IWvduPwA      2
# 3435  _nCRBi7_RLMkmjF8s6i0nw      1
# 3436  _A6nasik52sEurR1V7pp-Q      2
# 3437  ICoXyycwU0r3dpikBs5UlQ      2
# 3441  6Cc72bI-OeUFDxUN2Ql8mg      2
# 3446  NGDIHjNTHuJeop9GEyBYOg      2
# 3447  j7inVDSpw9USpSjQ8t47sA      1
# 3454  eNfnyllvw_EoIVJt7kqvXA      2
# 3458  kwiEG_KCpDB6aK5fTSM7iw      2
# 3463  ragZwT6uv4MPQHLeEXmkOA      2
# 3466  jwNEkZAww5eXT8H7pYjWrQ      2
# 3471  1KZB1c0O-NnFvWb2S89Ulw      2
# 3476  cWmt1IL2Fk538I-N1ghOCg      1
# 3482  6I-AqQMNOF9SbK7WaPUSIA      2
# 3491  7Xk_gdsvENqKS0qWMu5cug      2
#
#                                                    text  useful  \
# 0     The pizza was okay. Not the best I've had. I p...       0
# 2     Terrible. Dry corn bread. Rib tips were all fa...       3
# 3     Back in 2005-2007 this place was my FAVORITE t...       2
# 5     This place sucks. The customer service is horr...       2
# 11    The score should be negative. Its HORRIBLE. Th...       0
# 21    Food was alright, the service was HORRIBLE! Bo...       1
# 23    If I could leave zero stars I would. This rude...       4
# 26    I wish i could tell you all about the food but...       1
# 32    Limited vegetarian options. Ordered Greek sala...       0
# 38    Non-existened service!  The waiter did not eve...       0
# 40    This place doesn't even deserve 1 star. Horrib...      18
# 44    Easy access to the store with ample parking. I...       1
# 45    Been here 3x and no beef #45, will stop coming...       0
# 46    In case my email didn't work, still giving a 1...       0
# 49    Drive thru: I guess it's opposite day at the d...       0
# 54    2.5 stars. We've come here several times over ...       0
# 55    Meh. 6 skinny mozzarella sticks for $7. It's a...       1
# 60    Regular starbucks, nothing special. No one exc...       0
# 72    Food taste: 2 \nTime to receive food: 3\nCusto...       1
# 76    First and last time at this location. We've be...       0
# 79    Horrible. The smart ones have closed their acc...       1
# 86    Where to begin? 1st timer at AMC Desert Ridge....       4
# 91    I would have to say my husband and I are very ...       9
# 93    Probably the worst experience at a hotel in Ve...       0
# 94    People please...the only good thing about this...       2
# 98    STAY AWAY!!! Because I moved this was the clos...       5
# 102   2 of my girlfriends recommended this place so ...       1
# 122   One of the worst bar experiences I've ever had...       1
# 123   I know some people are going to completely dis...       5
# 132   For those that don't know, O.Noir is that uniq...      15
# ...                                                 ...     ...
# 3375  Sadly this place has gone downhill since it ch...       0
# 3383  Highly disappointed in this place.  First of a...       0
# 3385  First of all we wanted to try this place for t...       0
# 3386  I decided to try this place and it was the wor...       2
# 3387  The Parma location needs help, BADLY!\n\nThe m...       0
# 3390  Went for the first time and they gave me a sta...       0
# 3394  Absolutely.. Terrible. Just got my cut done so...       1
# 3395  Come here for all your smoke goods.. NOT YOUR ...       2
# 3403  Got the wrong order twice, took almost an hour...       0
# 3405  Dirty. Old. Elevators do not work well. Poor s...       0
# 3411  First time trying Paramount Fine Foods - heard...       2
# 3416  There are way better places to get your fix of...       3
# 3418  Restaurant was busy for a weeknight and we fig...       3
# 3421  I've been here a few times and have been disap...       0
# 3424  I've been here a quite a few times over the la...       1
# 3428  Overpriced and really disorganized - and it wa...       3
# 3435  Waitress we had was rudeeeeeeeee! She was rude...       1
# 3436  2.5 stars\n\nHalf star earned only because I h...       3
# 3437  Messini on the Danforth is one of my favourite...       0
# 3441  I've been here many times over the years and t...       0
# 3446  Food was okay - as others have pointed out, a ...       0
# 3447  I wish they had a zero star rating option here...       7
# 3454  Appetizer was good - had the deep fried shrimp...       1
# 3458  We were expecting amazing Thai food after all ...       1
# 3463  I really wanted to like this place.  I really ...       0
# 3466  Had lunch here a few weeks ago - I was quite d...       0
# 3471  Updated review (keeping 2 stars) after having ...       8
# 3476  I stopped in here for a haircut a little over ...       1
# 3482  Oh, Coffee Plantation, where didst thou self-r...       2
# 3491  After hearing a friend talk about this place l...       3
#
#                      user_id  score
# 0     msQe1u7Z_XuqjGoqhB0J5g   -0.1
# 2     msQe1u7Z_XuqjGoqhB0J5g   -0.3
# 3     msQe1u7Z_XuqjGoqhB0J5g   -0.2
# 5     msQe1u7Z_XuqjGoqhB0J5g   -0.6
# 11    NhOc64RsrTT1Dls50yYW8g   -0.5
# 21    5ngpW5tf3ep680eG1HxHzA   -0.5
# 23    eAavwM32i2h7sNNer--kGw   -0.3
# 26    Fc_nb6N6Sdurqb-rwsY1Bw   -0.5
# 32    B7Fh30KQT1xPSGt_pIhRRA   -0.4
# 38    FCtoTo9zSH1cSAkascfEHw   -0.5
# 40    Ka7TIp74VHSa90rfdg4_2g   -0.7
# 44    0pf5VuzE4_1pwj5NJHG5TQ   -0.1
# 45    0pf5VuzE4_1pwj5NJHG5TQ   -0.3
# 46    0pf5VuzE4_1pwj5NJHG5TQ   -0.5
# 49    0pf5VuzE4_1pwj5NJHG5TQ   -0.4
# 54    0pf5VuzE4_1pwj5NJHG5TQ   -0.1
# 55    0pf5VuzE4_1pwj5NJHG5TQ   -0.1
# 60    0pf5VuzE4_1pwj5NJHG5TQ   -0.1
# 72    0pf5VuzE4_1pwj5NJHG5TQ   -0.3
# 76    0pf5VuzE4_1pwj5NJHG5TQ   -0.1
# 79    0pf5VuzE4_1pwj5NJHG5TQ   -0.3
# 86    0pf5VuzE4_1pwj5NJHG5TQ   -0.1
# 91    AYYKxiTdfsPIOBo3MqfAUg   -0.4
# 93    ndEeYBva8wU1N_vzfvOhEQ   -0.3
# 94    0AIj432MvowwghnpurtP-Q   -0.6
# 98    Yy_iGXxLpL6tYDQoE-6XVg   -0.3
# 102   Yy_iGXxLpL6tYDQoE-6XVg   -0.6
# 122   YHWsLBS8jzZiPjKHMFOaAA   -0.4
# 123   YHWsLBS8jzZiPjKHMFOaAA   -0.5
# 132   YHWsLBS8jzZiPjKHMFOaAA   -0.4
# ...                      ...    ...
# 3375  CoCkuPtRB3cYZaHlAI-Vbg   -0.1
# 3383  BJNcLl4SHRdXlz0RUC7E-g   -0.6
# 3385  BJNcLl4SHRdXlz0RUC7E-g   -0.3
# 3386  BJNcLl4SHRdXlz0RUC7E-g   -0.8
# 3387  li1wApM75XJNpYjo_uqsLg   -0.4
# 3390  ywe_fvZcN3KSIEKapjE6Rg   -0.6
# 3394  ywe_fvZcN3KSIEKapjE6Rg   -0.2
# 3395  ywe_fvZcN3KSIEKapjE6Rg   -0.5
# 3403  iL42nhZyqGGNuX9Vj379KA   -0.5
# 3405  -Zdxj4wuj4D_899B7tPE3g   -0.5
# 3411  PkRFSQgSfca9Tamq7b2LdQ   -0.1
# 3416  PkRFSQgSfca9Tamq7b2LdQ   -0.2
# 3418  PkRFSQgSfca9Tamq7b2LdQ   -0.1
# 3421  PkRFSQgSfca9Tamq7b2LdQ   -0.3
# 3424  PkRFSQgSfca9Tamq7b2LdQ   -0.4
# 3428  PkRFSQgSfca9Tamq7b2LdQ   -0.6
# 3435  PkRFSQgSfca9Tamq7b2LdQ   -0.4
# 3436  PkRFSQgSfca9Tamq7b2LdQ   -0.2
# 3437  PkRFSQgSfca9Tamq7b2LdQ   -0.1
# 3441  PkRFSQgSfca9Tamq7b2LdQ   -0.3
# 3446  PkRFSQgSfca9Tamq7b2LdQ   -0.1
# 3447  PkRFSQgSfca9Tamq7b2LdQ   -0.3
# 3454  PkRFSQgSfca9Tamq7b2LdQ   -0.1
# 3458  PkRFSQgSfca9Tamq7b2LdQ   -0.4
# 3463  PkRFSQgSfca9Tamq7b2LdQ   -0.2
# 3466  PkRFSQgSfca9Tamq7b2LdQ   -0.1
# 3471  JMMn2pW2mRFgtfy9p8ovtg   -0.3
# 3476  s2SbRhL14fDSGkQ14k8bFg   -0.4
# 3482  dnSBTYaCnKk_zxjAic1QEQ   -0.4
# 3491  dnSBTYaCnKk_zxjAic1QEQ   -0.1
#
# [808 rows x 10 columns]

# %% [markdown]
# A good review is the review with more than 2 useful upvote

# %%
df_good_review = pd.read_sql_query("select * from review where useful>2",conn)

# %%
df_good_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 926606 entries, 0 to 926605
# Data columns (total 9 columns):
# business_id    926606 non-null object
# cool           926606 non-null int64
# date           926606 non-null object
# funny          926606 non-null int64
# review_id      926606 non-null object
# stars          926606 non-null int64
# text           926606 non-null object
# useful         926606 non-null int64
# user_id        926606 non-null object
# dtypes: int64(4), object(5)
# memory usage: 63.6+ MB

# %%
df_good_review_4000 = df_good_review.loc[:4000,]

# %%
df_good_review_4000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
# business_id    4001 non-null object
# cool           4001 non-null int64
# date           4001 non-null object
# funny          4001 non-null int64
# review_id      4001 non-null object
# stars          4001 non-null int64
# text           4001 non-null object
# useful         4001 non-null int64
# user_id        4001 non-null object
# dtypes: int64(4), object(5)
# memory usage: 281.4+ KB

# %%
df_good_review_4000['score'],df_good_review_4000['score_magnitude'] = zip(*df_good_review_4000['text'].apply(lambda text: AnalyseSentiment(text)))
df_good_review_4000.head()
# Out:
# /Users/jixingwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#               business_id  cool                        date  funny  \
# 0  jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23 00:00:00.000000      1
# 1  3Mx4renubPRnjHUw1n2UkA     0  2015-09-30 00:00:00.000000      1
# 2  qdC2h3MqCNussc5lhzL7gg     0  2015-11-05 00:00:00.000000      0
# 3  brVIRXT4AubkUbe6P-NAAA     0  2016-05-01 00:00:00.000000      0
# 4  Wc9UpJhOcdSj7olZkz7SJA     0  2016-04-11 00:00:00.000000      0
#
#                 review_id  stars  \
# 0  LZp4UX5zK3e-c5ZGSeo3kA      1
# 1  MTrzrLQT_LK2VLK9xantHw      1
# 2  AJ0IglpYAp2D0daOlVGIdg      1
# 3  IRw-bVzY_9ASqmeDLzXPig      3
# 4  dbfzieXNqQLsZjE7BSRZXg      3
#
#                                                 text  useful  \
# 0  Terrible. Dry corn bread. Rib tips were all fa...       3
# 1  If I could leave zero stars I would. This rude...       4
# 2  This place doesn't even deserve 1 star. Horrib...      18
# 3  Laser maze is a blast for the kids, check Grou...       3
# 4  First time here started off with no line, by t...       6
#
#                   user_id  score  score_magnitude
# 0  msQe1u7Z_XuqjGoqhB0J5g   -0.3              2.0
# 1  eAavwM32i2h7sNNer--kGw   -0.3              4.9
# 2  Ka7TIp74VHSa90rfdg4_2g   -0.7              4.4
# 3  0pf5VuzE4_1pwj5NJHG5TQ    0.2              2.9
# 4  0pf5VuzE4_1pwj5NJHG5TQ    0.0              3.2

# %%
df_good_review_4000.to_csv('good_review.csv')

# %% [markdown]
# **google's NLP api is expensive, can't afford it. Must try to something else**

# %% [markdown]
# # Comparison textblob with Google's NLP api

# %%
df_good_review_4000['textblob_score'] = df_good_review_4000['text'].apply(lambda text: TextBlob(text).sentiment[0]*TextBlob(text).sentiment[1])
# Out:
# /Users/jixingwei/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_good_review_4000[['textblob_score','score']].head()
# Out:
#    textblob_score  score
# 0       -0.426667   -0.3
# 1       -0.003218   -0.3
# 2       -0.520000   -0.7
# 3        0.278819    0.2
# 4        0.113850    0.0
