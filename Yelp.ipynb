# %%
key = "myiehrlImSEu0GOj4V2FzswMPhpyVxUgGC5k5m_asaaYvmfTeBcUNnRGamxeTTqqHWW9Autb3gz-CMpT6_VNQPs5UZr5he4c_UjT_NrSagIJQIQEamLvqhclnd3oW3Yx"

# %%
import requests

# %%
params = {'term': 'food', 'location': 'Sacramento','limit':50}

# %%
url = "https://api.yelp.com/v3/businesses/search"

# %%
headers = {
        'Authorization': 'Bearer %s' % key,
    }

# %%
req = requests.get(url,params=params,headers=headers)

# %%
js = req.json()

# %%
js['businesses']
# Out:
# [{'id': 'eFhpQCpS_iCdZ749f31-zA',
#   'alias': 'ramen-house-ryujin-sacramento',
#   'name': 'Ramen House Ryujin',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/bsL_mGRaZDijME3LcnqOmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ramen-house-ryujin-sacramento?adjust_creative=Ooi_wiMiDX1tz--3YmUzCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ooi_wiMiDX1tz--3YmUzCQ',
#   'review_count': 2374,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 38.5674, 'longitude': -121.4857},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '1831 S St',
#    'address2': '',
#    'address3': '',
#    'city': 'Sacramento',
#    'zip_code': '95811',
#    'country': 'US',
#    'state': 'CA',
#    'display_address': ['1831 S St', 'Sacramento, CA 95811']},
#   'phone': '+19163410488',
#   'display_phone': '(916) 341-0488',
# ...

# %%
params2 = {'term': 'food', 'location': 'Sacramento','limit':50,'offset':50}

# %%
req2 = requests.get(url,params=params2,headers=headers)

# %%
req2.json()
# Out:
# {'businesses': [{'id': 'b_bN3q16Ru773fU4ct6axw',
#    'alias': 'raretea-sacramento',
#    'name': 'RareTea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/100deyIvKufZd1HYEPstiQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/raretea-sacramento?adjust_creative=Ooi_wiMiDX1tz--3YmUzCQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ooi_wiMiDX1tz--3YmUzCQ',
#    'review_count': 26,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'tea', 'title': 'Tea Rooms'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 38.5811402323152,
#     'longitude': -121.50107641708},
#    'transactions': [],
#    'location': {'address1': '414 K St',
#     'address2': 'Ste 225',
#     'address3': None,
#     'city': 'Sacramento',
#     'zip_code': '95814',
#     'country': 'US',
#     'state': 'CA',
#     'display_address': ['414 K St', 'Ste 225', 'Sacramento, CA 95814']},
#    'phone': '+19169429903',
# ...
